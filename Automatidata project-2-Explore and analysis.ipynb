# %% [markdown]
# ## **Conclusion**
#
# As a result of the conducted exploratory data analysis, considering trip distance and total amount as key variables to depict a taxi cab ride. The provided scatter plot shows the relationship between the two variables.

# %% [markdown]
# ## **Exploring and Analyzing Data**

# %% [markdown]
# #### **Import packages**

# %%
# Import packages and libraries
try:
    import pandas as pd
    import matplotlib.pyplot as plt
    import numpy as np
    import datetime as dt
    import seaborn as sns
    print("Import successfully")
except:
    print("Import fail")
# Out:
# Import successfully

# %%
# Load dataset into dataframe
df = pd.read_csv('2017_Yellow_Taxi_Trip_Data.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0    24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1    35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2   106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3    38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4    30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
# 5    23345809         2   03/25/2017 8:34:11 PM   03/25/2017 8:42:11 PM
# 6    37660487         2   05/03/2017 7:04:09 PM   05/03/2017 8:03:47 PM
# 7    69059411         2   08/15/2017 5:41:06 PM   08/15/2017 6:03:05 PM
# 8     8433159         2   02/04/2017 4:17:07 PM   02/04/2017 4:29:14 PM
# 9    95294817         1   11/10/2017 3:20:29 PM   11/10/2017 3:40:55 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# ...

# %%
df.size
# Out:
# 408582

# %%
df.describe()
# Out:
#          Unnamed: 0      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %% [markdown]
# #### **Modify datatype**

# %%
# Convert data columns to datetime
df["tpep_pickup_datetime"] = pd.to_datetime(df["tpep_pickup_datetime"])
df["tpep_dropoff_datetime"] = pd.to_datetime(df["tpep_dropoff_datetime"])

# %% [markdown]
# #### **Check the distribution of  data**

# %% [markdown]
# #### `trip_distance`
#
# _The distance for each trip_

# %%
# Create box plot of trip_distance
plt.figure(figsize = (7, 2))
plt.title("trip_distance")
sns.boxplot(data  = None, x = df["trip_distance"], fliersize = 3)
# Out:
# <Axes: title={'center': 'trip_distance'}, xlabel='trip_distance'>

# %%
# Create histogram of trip_distance
plt.figure(figsize = (14, 7))
plt.title("Trip distance histpgram")
sns.histplot(df["trip_distance"], bins = range(0, 26, 1))
# Out:
# <Axes: title={'center': 'Trip distance histpgram'}, xlabel='trip_distance', ylabel='Count'>

# %% [markdown]
# #### `total_amount`
#
# _The total amount of payment for each trip_

# %%
# Create histogram of total_amount
plt.figure(figsize = (14, 7))
ax = sns.histplot(df["total_amount"], bins = range(-10, 101, 5))
ax.set_xticks(range(-10, 101, 5))
ax.set_xticklabels(range(-10, 101, 5))
plt.title("Total amount histogram")
# Out:
# Text(0.5, 1.0, 'Total amount histogram')

# %% [markdown]
# #### `tip_amount`
#
# _The amount of tip for each trip_

# %%
# Create box plot of tip_amount
plt.figure(figsize = (7, 2))
plt.title("tip_amount")
sns.boxplot(x = df["tip_amount"], fliersize = 3)
# Out:
# <Axes: title={'center': 'tip_amount'}, xlabel='tip_amount'>

# %%
# Create histogram of tip_amount
plt.figure(figsize = (14, 7))
ax = sns.histplot(df["tip_amount"], bins = range(0, 21, 1))
ax.set_xticks(range(0, 21, 2))
ax.set_xticklabels(range(0, 21, 2))
plt.title("Tip amount histogram")
# Out:
# Text(0.5, 1.0, 'Tip amount histogram')

# %% [markdown]
# #### **Check the amount of tip for different vendor**

# %%
# Create histogram of tip_amount by vendor
plt.figure(figsize = (14, 7))
ax = sns.histplot(data = df, x = "tip_amount", bins = range(0, 21, 1),
                  hue = "VendorID",
                  multiple = "stack",
                  palette = "pastel")
ax.set_xticks(range(0, 21, 1))
ax.set_xticklabels(range(0, 21, 1))
plt.title("Tip amount by vendor histogram")
# Out:
# Text(0.5, 1.0, 'Tip amount by vendor histogram')

# %%
# Create histogram of tip_amount by vendor for tips > $10 
tips_over_ten = df[df["tip_amount"] > 10]
plt.figure(figsize = (14, 7))
ax = sns.histplot(data = tips_over_ten, x = 'tip_amount', bins = range(10, 21, 1), 
                  hue = 'VendorID', 
                  multiple = 'stack',
                  palette = 'pastel')
ax.set_xticks(range(10, 21, 1))
ax.set_xticklabels(range(10, 21, 1))
plt.title('Tip amount by vendor histogram');

# %% [markdown]
# #### **Check the amount of tip for each `passenger_count`**

# %%
df["passenger_count"].value_counts()
# Out:
# passenger_count
# 1    16117
# 2     3305
# 5     1143
# 3      953
# 6      693
# 4      455
# 0       33
# Name: count, dtype: int64

# %%
# Calculate mean tips by passenger_count
mean_tips_by_passenger_count = df.groupby(["passenger_count"]).mean(numeric_only = True)[["tip_amount"]]
mean_tips_by_passenger_count
# Out:
#                  tip_amount
# passenger_count
# 0                  2.135758
# 1                  1.848920
# 2                  1.856378
# 3                  1.716768
# 4                  1.530264
# 5                  1.873185
# 6                  1.720260

# %%
# Create bar plot for mean tips by passenger count
data = mean_tips_by_passenger_count.tail(-1)
pal = sns.color_palette("Greens_d", len(data))
rank = data["tip_amount"].argsort().argsort()
plt.figure(figsize = (14, 7))
ax = sns.barplot(x = data.index,
                 y = data["tip_amount"],
                 palette = np.array(pal[::-1])[rank])
ax.axhline(df["tip_amount"].mean(), ls = "--", color = "red", label = "global mean")
ax.legend()
plt.title("mena tip amout by passenger count", fontsize = 16)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22500\3778756397.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x = data.index,
# C:\Users\PC\AppData\Local\Temp\ipykernel_22500\3778756397.py:6: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   ax = sns.barplot(x = data.index,
# Text(0.5, 1.0, 'mena tip amout by passenger count')

# %% [markdown]
# #### **Check the average ride for each month and day**

# %% [markdown]
# #### **Create month and day columns**

# %%
# Create a month column
df["month"] = df["tpep_pickup_datetime"].dt.month_name()
# Create a day column
df["day"] = df["tpep_pickup_datetime"].dt.day_name()

# %%
# Get total number of rides for each month
monthly_rides = df["month"].value_counts()
monthly_rides
# Out:
# month
# March        2049
# October      2027
# April        2019
# May          2013
# January      1997
# June         1964
# December     1863
# November     1843
# February     1769
# September    1734
# August       1724
# July         1697
# Name: count, dtype: int64

# %%
# Reorder the monthly ride list so months go in order
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
         'August', 'September', 'October', 'November', 'December']
monthly_rides = monthly_rides.reindex(index=month_order)
monthly_rides
# Out:
# month
# January      1997
# February     1769
# March        2049
# April        2019
# May          2013
# June         1964
# July         1697
# August       1724
# September    1734
# October      2027
# November     1843
# December     1863
# Name: count, dtype: int64

# %%
# Show the index
monthly_rides.index
# Out:
# Index(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype='object', name='month')

# %%
# Create a bar plot of total rides per month
plt.figure(figsize = (14, 7))
ax = sns.barplot(x = monthly_rides.index, 
                 y = monthly_rides,
                 palette="rainbow")
ax.set_xticklabels(month_order)
plt.title("Ride count by month", fontsize = 16)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22500\3138252541.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x = monthly_rides.index,
# C:\Users\PC\AppData\Local\Temp\ipykernel_22500\3138252541.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(month_order)
# Text(0.5, 1.0, 'Ride count by month')

# %%
# Repeat the above process, this time for rides by day
daily_rides = df['day'].value_counts()
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
daily_rides = daily_rides.reindex(index=day_order)
daily_rides
# Out:
# day
# Monday       2931
# Tuesday      3198
# Wednesday    3390
# Thursday     3402
# Friday       3413
# Saturday     3367
# Sunday       2998
# Name: count, dtype: int64

# %%
# Create bar plot for ride count by day
plt.figure(figsize=(14,7))
ax = sns.barplot(x=daily_rides.index, 
                 y=daily_rides, 
                 palette="rainbow")
ax.set_xticklabels(day_order)
plt.title('Ride count by day', fontsize=16);
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22500\1575466733.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=daily_rides.index,
# C:\Users\PC\AppData\Local\Temp\ipykernel_22500\1575466733.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(day_order)

# %%
# Repeat the process, this time for total revenue by day
total_amount_day = df.groupby('day')[['total_amount']].sum()
total_amount_day = total_amount_day.reindex(index=day_order)
total_amount_day
# Out:
#            total_amount
# day
# Monday         49574.37
# Tuesday        52527.14
# Wednesday      55310.47
# Thursday       57181.91
# Friday         55818.74
# Saturday       51195.40
# Sunday         48624.06

# %%
# Create bar plot of total revenue by day
plt.figure(figsize=(12,7))
ax = sns.barplot(x=total_amount_day.index, 
                 y=total_amount_day['total_amount'],
                 palette="rainbow")
ax.set_xticklabels(day_order)
ax.set_ylabel('Revenue (USD)')
plt.title('Total revenue by day', fontsize=16)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22500\1655275468.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=total_amount_day.index,
# C:\Users\PC\AppData\Local\Temp\ipykernel_22500\1655275468.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(day_order)
# Text(0.5, 1.0, 'Total revenue by day')

# %%
# Repeat the process, this time for total revenue by month
total_amount_month = df.groupby('month')[['total_amount']].sum()
total_amount_month = total_amount_month.reindex(index=month_order)
total_amount_month
# Out:
#            total_amount
# month
# January        31735.25
# February       28937.89
# March          33085.89
# April          32012.54
# May            33828.58
# June           32920.52
# July           26617.64
# August         27759.56
# September      28206.38
# October        33065.83
# November       30800.44
# December       31261.57

# %%
# Create a bar plot of total revenue by month
plt.figure(figsize=(12,7))
ax = sns.barplot(x=total_amount_month.index, 
                 y=total_amount_month['total_amount'],
                 palette="rainbow")
plt.title('Total revenue by month', fontsize=16)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22500\1485302466.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=total_amount_month.index,
# Text(0.5, 1.0, 'Total revenue by month')

# %% [markdown]
# #### **Check the mean trip distance by drop-off location**

# %% [markdown]
# `DOLocationID`
#
# _Drop off location ID_

# %%
# Get number of unique drop-off location IDs
df["DOLocationID"].nunique()
# Out:
# 216

# %%
# Calculate the mean trip distance for each drop-off location
distance_by_dropoff = df.groupby("DOLocationID")[["trip_distance"]].mean()
# Sort the results in descending order by mean trip distance
distance_by_dropoff = distance_by_dropoff.sort_values("trip_distance")
distance_by_dropoff
# Out:
#               trip_distance
# DOLocationID
# 207                1.200000
# 193                1.390556
# 237                1.555494
# 234                1.727806
# 137                1.818852
# ...                     ...
# 51                17.310000
# 11                17.945000
# 210               20.500000
# 29                21.650000
# 23                24.275000
#
# [216 rows x 1 columns]

# %%
# Create a bar plot of mean trip distances by drop-off location in ascending order by distance
plt.figure(figsize = (12, 7))
ax = sns.barplot(x = distance_by_dropoff.index,
                 y = distance_by_dropoff["trip_distance"],
                 order = distance_by_dropoff.index,
                 palette = "rainbow")
ax.set_xticks([])
ax.set_xticklabels([])
plt.title("Mean trip distance by drop-off location", fontsize = 16)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22500\4228653514.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x = distance_by_dropoff.index,
# Text(0.5, 1.0, 'Mean trip distance by drop-off location')

# %% [markdown]
# #### **Check if these mean trip distance are normal distribution**

# %% [markdown]
# ##### Create a normal distribution dataset

# %%
#1. Generate random points on a 2D plane from a normal distribution
test = np.round(np.random.normal(10, 5, (3000, 2)), 1)
midway = int(len(test)/2)  # Calculate midpoint of the array of coordinates
start = test[:midway]      # Isolate first half of array ("pick-up locations")
end = test[midway:]        # Isolate second half of array ("drop-off locations")

# 2. Calculate Euclidean distances between points in first half and second half of array
distances = (start - end)**2           
distances = distances.sum(axis=-1)
distances = np.sqrt(distances)

# 3. Group the coordinates by "drop-off location", compute mean distance
test_df = pd.DataFrame({'start': [tuple(x) for x in start.tolist()],
                   'end': [tuple(x) for x in end.tolist()],
                   'distance': distances})
sort_df = test_df.sort_values(by = ["distance"]).reset_index()
# 4. Plot the mean distance between each endpoint ("drop-off location") and all points it connected to
plt.figure(figsize=(12, 7))
ax = sns.barplot(x=sort_df.index,
                 y=sort_df['distance'],
                 palette = "rainbow")
ax.set_xticklabels([])
ax.set_xticks([])
ax.set_xlabel('Endpoint')
ax.set_ylabel('Mean distance to all other points')
ax.set_title('Mean distance between points taken randomly from normal distribution')
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22500\987988782.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sort_df.index,
# Text(0.5, 1.0, 'Mean distance between points taken randomly from normal distribution')

# %% [markdown]
# #### Plot the rides for each location

# %%
# Check if all drop-off locations are consecutively numbered
df['DOLocationID'].max() - len(set(df['DOLocationID']))
# Out:
# 49

# %%
plt.figure(figsize = (16, 4))
# DOLocationID column is numeric, so sort in ascending order
sorted_dropoffs = df["DOLocationID"].sort_values()

# Convert to string ready for plot
sorted_dropoffs = sorted_dropoffs.astype("str")

# Plot
sns.histplot(data = sorted_dropoffs)
plt.xticks([])
plt.xlabel("Drop-off locations")
plt.title("Histogram of rides by drop-off location", fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Histogram of rides by drop-off location')

# %%
df = df[(df["total_amount"] < 200) & (df["total_amount"] > 0)]
sns.scatterplot(x = df["total_amount"],
                y = df["trip_distance"],
                hue = df["trip_distance"] == 0)
plt.legend(title = "Trip Distance = 0")
